# %% [markdown]
# **LIBRARIES**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Initial Exploration of Data**

# %%
import pandas as pd

df = pd.read_csv("/content/Financial Analytics data.csv")
print(df)
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0        1   Reliance Inds.        583436.72           99810.00         NaN
# 1        2              TCS        563709.84           30904.00         NaN
# 2        3        HDFC Bank        482953.59           20581.27         NaN
# 3        4              ITC        320985.27            9772.02         NaN
# 4        5          H D F C        289497.37           16840.51         NaN
# ..     ...              ...              ...                ...         ...
# 483    496  Lak. Vilas Bank          3029.57             790.17         NaN
# 484    497            NOCIL          3026.26             249.27         NaN
# 485    498    Orient Cement          3024.32             511.53         NaN
# 486    499  Natl.Fertilizer          3017.07            2840.75         NaN
# 487    500        L T Foods              NaN                NaN         NaN
#
# [488 rows x 5 columns]

# %%
df.head(500)
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0        1   Reliance Inds.        583436.72           99810.00         NaN
# 1        2              TCS        563709.84           30904.00         NaN
# 2        3        HDFC Bank        482953.59           20581.27         NaN
# 3        4              ITC        320985.27            9772.02         NaN
# 4        5          H D F C        289497.37           16840.51         NaN
# ..     ...              ...              ...                ...         ...
# 483    496  Lak. Vilas Bank          3029.57             790.17         NaN
# 484    497            NOCIL          3026.26             249.27         NaN
# 485    498    Orient Cement          3024.32             511.53         NaN
# 486    499  Natl.Fertilizer          3017.07            2840.75         NaN
# 487    500        L T Foods              NaN                NaN         NaN
#
# [488 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['S.No.', 'Name', 'Mar Cap - Crore', 'Sales Qtr - Crore', 'Unnamed: 4'], dtype='object')

# %%
df.dtypes
# Out:
# S.No.                  int64
# Name                  object
# Mar Cap - Crore      float64
# Sales Qtr - Crore    float64
# Unnamed: 4           float64
# dtype: object

# %%
df.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore   Unnamed: 4
# count  488.000000       479.000000         365.000000    94.000000
# mean   251.508197     28043.857119        4395.976849  1523.870106
# std    145.884078     59464.615831       11092.206185  1800.008836
# min      1.000000      3017.070000          47.240000     0.000000
# 25%    122.750000      4843.575000         593.740000   407.167500
# 50%    252.500000      9885.050000        1278.300000   702.325000
# 75%    378.250000     23549.900000        2840.750000  2234.815000
# max    500.000000    583436.720000      110666.930000  7757.060000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['S.No.'].plot(kind='hist', bins=20, title='S.No.')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# **Univariate Analysis**

# %% [markdown]
# Margin Captilisation looks like?

# %%
sns.distplot(df['Mar Cap - Crore'])
plt.axvline(x=np.mean(df['Mar Cap - Crore']),c='Red',ls='--',label='mean')
plt.axvline(x=np.percentile(df['Mar Cap - Crore'],25),c='green',ls='--',label='25-75th percentile')
plt.axvline(x=np.percentile(df['Mar Cap - Crore'],25),c='green',ls='--')
plt.legend()

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'S.No.'}>,
#         <Axes: title={'center': 'Mar Cap - Crore'}>],
#        [<Axes: title={'center': 'Sales Qtr - Crore'}>,
#         <Axes: title={'center': 'Unnamed: 4'}>]], dtype=object)

# %% [markdown]
# Sales Qtr looks like?

# %%
sns.distplot(df['Sales Qtr - Crore'])
plt.axvline(x=np.mean(df['Sales Qtr - Crore']),c='Red',ls='--',label='mean')
plt.axvline(x=np.percentile(df['Sales Qtr - Crore'],25),c='green',ls='--',label='25-75th percentile')
plt.axvline(x=np.percentile(df['Sales Qtr - Crore'],25),c='green',ls='--')
plt.legend()

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'S.No.'}>,
#         <Axes: title={'center': 'Mar Cap - Crore'}>],
#        [<Axes: title={'center': 'Sales Qtr - Crore'}>,
#         <Axes: title={'center': 'Unnamed: 4'}>]], dtype=object)

# %% [markdown]
# **Dealing with missing values**

# %%
df.duplicated().sum()
# Out:
# 0
